# %% [markdown]
# ## Samarth Motka
# ## 202311023
# ## Lab 7

# %% [markdown]
# #1 Write your Python code to perform global and local thresholding on a given image (fig 1), along with a report discussing the impact of different threshold values on the segmentation results.

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/1.jpeg', cv2.IMREAD_GRAYSCALE)  # 0 means load in grayscale

# Global thresholding
_, global_thresh = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Local thresholding using adaptive mean thresholding
local_thresh = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                     cv2.THRESH_BINARY, 11, 2)

# Display results
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(global_thresh, cmap='gray')
plt.title('Global Thresholding')

plt.subplot(1, 3, 3)
plt.imshow(local_thresh, cmap='gray')
plt.title('Local Thresholding')

plt.tight_layout()
plt.show()

# %% [markdown]
# #2 Write a Python code for performing segmentation using K-means clustering on a given image (fig 1).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/1.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Reshape the image to a 2D array of pixels
pixels = image.reshape((-1, 3))

# Convert to float for more precision
pixels = np.float32(pixels)

# Define criteria, number of clusters(K) and apply kmeans()
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2)
K = 3
_, labels, centers = cv2.kmeans(pixels, K, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# Convert back to 8 bit values
centers = np.uint8(centers)

# Map the labels to the original image dimensions
segmented_image = centers[labels.flatten()]
segmented_image = segmented_image.reshape(image.shape)

# Display the result
plt.imshow(segmented_image)
plt.title('Segmented Image with K-means Clustering')
plt.show()

# %% [markdown]
# # 3 Write a Python code for detecting edges by using a canny edge detection algorithm on a given image (fig 2).

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/lena_face.jpg', cv2.IMREAD_GRAYSCALE)

# Apply Canny edge detector
edges = cv2.Canny(image, 100, 200)

# Display the result
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection using Canny')
plt.show()
